# %%
import sys
import os   
import requests
import pandas as pd
import json
import yaml
from datetime import datetime, timedelta
import datetime as dt

from snowflake.snowpark.functions import date_trunc, current_date
from snowflake.snowpark.functions import col, lit, when
from snowflake.snowpark.types import DateType
import snowflake.snowpark.functions as f


sys.path.append(os.path.abspath('../scripts'))
try:
    from snowflake.snowpark.context import get_active_session
    session = get_active_session()
except Exception:
    from SnowflakeConnector import create_active_session
    session = create_active_session()

# %%
table = session.table('analytics.analytics.shop_orders_with_attribution').show()
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"CHANNEL"          |"ORDER_COMPLETED_DATE"  |"PROCESSED_AT"             |"ORDER_NUMBER"  |"ORDER_ID"     |"TIMESTAMP"                 |"SESSION_ID"                               |"ANONYMOUS_ID"                        |"USER_ID"  |"CUSTOMER__ID"  |"EMAIL"                 |"TAGS"                                              |"EVENT_ID"                                 |"UTM_MCID_BLUEPRINT"  |"LANDING_PAGE"       |"PAGE_URL_QUERY"  |"UTM_CAMPAIGN"  |"ORDER_LAST_TOUCH_CAMPAIGN"  |"ORDER_LAST_TOUCH_SOURCE"  |"ORDER_LAST_TOUCH_MEDIUM"  |"ORDER_LAST_TOUCH_REFERRER"                         |"ORDER_LAST_TOUCH_CONTENT"  |"UTM_TERM"  |"ORDER_LAST_TOUCH_TERM"  |"ORDER_LAST_TOUCH_CAMPAIGN_ID"  |"ORDER_LAST_TOUCH_AD_ID"  |"ORDER_LAST_TOUCH_ADGROUP_ID"  |"LAST_TOUCH_MCID"  |"LAST_TOUCH_ITC_CONTENT"  |"SESSION_LANDING_URL"                               |"SESSION_MCID"  |"SESSION_MEDIUM"  |"SESSION_CAMPAIGN"   |"TOTAL_NET_REVENUE"  |"NEW_SUP_CUST"  |"NEW_PC_CUST"  |"OCTANE_CUST"  |"ORDER_CONTAINS_SUBSCRIPTION"  |"ORDER_CONTAINS_QUARTERLY"  |"UNITS"  |"SUBSCRIPTIONS_COUNT"  |"QUARTERLY_SUB_CT"  |"_20_DAY_SUB_CT"  |"SEMI_ANNUAL_SUB_CT"  |"BI_MONTHLY_SUB_CT"  |"MONTHLY_SUB_CT"  |"PAID_PLATFORM"  |"CLEAN_NAME"  |"CAMPAIGN_NAME"  |"BUSINESS_LINE"  |"FIRST_PRODUCT_ADDED"  |"FIRST_TOUCH_EMAIL_CAMPAIGN"         |"FIRST_TOUCH_EMAIL_NEWSLETTER"  |"LAST_TOUCH_EMAIL_CAMPAIGN"          |"AQUISITION_EMAIL_CAMPAIGN"          |"AQUISITION_NEWSLETTER"  |"ORDER_LAST_TOUCH_MCID"  |"EMAIL_CHANNEL"       |"ORDER_LAST_TOUCH_ADSET_ID"  |"ORDER_LAST_TOUCH_ADSET_NAME"  |"NEWSLETTER_COMBINED"  |"ROW_NUMBER"  |"CUST_ORDER_SEQ"  |"CUST_SUB_SEQ"  |"NEW_CUST"  |"NEW_SUBSCRIBER"  |"NEW_SUB_UPGRADE"  |"AFFILIATE_IN_SESSION"  |"AFFILIATE_CHECKOUT"  |"FIRST_AFFILIATE"  |"AFFILIATE_CHECKOUT_MEDIUM"  |"AFFILIATE_CHECKOUT_SOURCE"  |"AFFILIATE_CHECKOUT_CAMPAIGN"  |"EMAIL_SOURCE_ORDER_LIST"  |"CHANNEL_GROUP"  |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |Content            |2023-02-16              |2023-02-16 23:03:02+00:00  |283280          |5091741106281  |2023-02-16 23:03:36.277000  |53 - ea93f0a7-5f97-4fd8-90a3-657b14fc5c99  |ea93f0a7-5f97-4fd8-90a3-657b14fc5c99  |902760     |6167516250217   |jweaston@comcast.net    |first_recurring_order, recurring_order, Subscri...  |ajs-next-ef5b29d566171ddf2c4c3cae87a20796  |NULL                  |/products/d3         |NULL              |NULL            |NULL                         |NULL                       |NULL                       |NULL                                                |NULL                        |NULL        |NULL                     |NULL                            |NULL                      |NULL                           |NULL               |46245                     |https://www.mindbodygreen.com/articles/vitamin-...  |6190493         |email             |newsletter_20230215  |25.0                 |Yes             |No             |No             |Yes                            |NULL                        |1        |1                      |0                   |0                 |0                     |0                    |1                 |NULL             |NULL          |NULL             |NULL             |vitamin D3 potency+    |mbg daily revamp 2023-2-15-Iterable  |Daily                           |mbg daily revamp 2023-2-15-Iterable  |mbg daily revamp 2023-2-15-Iterable  |Daily                    |6190493                  |Content - Newsletter  |NULL                         |NULL                           |Daily                  |1             |1                 |1               |Yes         |Yes               |No                 |NULL                    |NULL                  |NULL               |NULL                         |NULL                         |NULL                           |["liveintent"]             |Content          |
# |Non-Site Activity  |2023-03-18              |2023-03-18 04:32:31+00:00  |295847          |5136738615401  |2023-03-18 04:32:31         |57 - ea93f0a7-5f97-4fd8-90a3-657b14fc5c99  |ea93f0a7-5f97-4fd8-90a3-657b14fc5c99  |902760     |6167516250217   |jweaston@comcast.net    |first_recurring_order, recurring_order, Subscri...  |api-2NAjogDsdlq0cGa83QohUmrZvRg            |NULL                  |NULL                 |NULL              |NULL            |NULL                         |NULL                       |NULL                       |NULL                                                |NULL                        |NULL        |NULL                     |NULL                            |NULL                      |NULL                           |NULL               |NULL                      |NULL                                                |NULL            |NULL              |NULL                 |25.0                 |No              |No             |No             |Yes                            |NULL                        |1        |1                      |0                   |0                 |0                     |0                    |1                 |NULL             |NULL          |NULL             |NULL             |NULL                   |NULL                                 |NULL                            |NULL                                 |mbg daily revamp 2023-2-15-Iterable  |Daily                    |NULL                     |NULL                  |NULL                         |NULL                           |Daily                  |1             |2                 |2               |No          |No                |No                 |NULL                    |NULL                  |NULL               |NULL                         |NULL                         |NULL                           |["liveintent"]             |Direct/Other     |
# |Non-Site Activity  |2023-04-17              |2023-04-17 04:40:41+00:00  |309106          |5184746193001  |2023-04-17 04:40:41         |61 - ea93f0a7-5f97-4fd8-90a3-657b14fc5c99  |ea93f0a7-5f97-4fd8-90a3-657b14fc5c99  |902760     |6167516250217   |jweaston@comcast.net    |first_recurring_order, recurring_order, Subscri...  |api-2OXUVh2xv0JiJJLc1uNmc3ayTZq            |NULL                  |NULL                 |NULL              |NULL            |NULL                         |NULL                       |NULL                       |NULL                                                |NULL                        |NULL        |NULL                     |NULL                            |NULL                      |NULL                           |NULL               |NULL                      |NULL                                                |NULL            |NULL              |NULL                 |25.0                 |No              |No             |No             |Yes                            |NULL                        |1        |1                      |0                   |0                 |0                     |0                    |1                 |NULL             |NULL          |NULL             |NULL             |NULL                   |NULL                                 |NULL                            |NULL                                 |mbg daily revamp 2023-2-15-Iterable  |Daily                    |NULL                     |NULL                  |NULL                         |NULL                           |Daily                  |1             |3                 |3               |No          |No                |No                 |NULL                    |NULL                  |NULL               |NULL                         |NULL                         |NULL                           |["liveintent"]             |Direct/Other     |
# |Affiliate          |2020-09-11              |2020-09-11 21:56:50+00:00  |31101           |2686874452073  |2020-09-11 21:56:50         |6 - 8d842e74-abfc-4cfd-9bb7-4b5e21344eb0   |8d842e74-abfc-4cfd-9bb7-4b5e21344eb0  |NULL       |3487133892713   |schat.bailey@gmail.com  |first_recurring_order, recurring_order              |api-1hNpV1sYoUu2BzD9CmYmjTZhb12            |NULL                  |/products/magnesium  |NULL              |553813          |553813                       |sas                        |affiliate                  |https://www.shareasale-analytics.com/r.cfm?b=15...  |NULL                        |NULL        |NULL                     |NULL                            |NULL                      |NULL                           |NULL               |NULL                      |https://shop.mindbodygreen.com/products/magnesium   |NULL            |affiliate         |3371698.d3edb0       |49.0                 |Yes             |No             |No             |Yes                            |NULL                        |1        |1                      |0                   |0                 |0                     |0                    |1                 |NULL             |NULL          |NULL             |NULL             |magnesium+             |NULL                                 |NULL                            |NULL                                 |NULL                                 |NULL                     |NULL                     |NULL                  |NULL                         |NULL                           |NULL                   |1             |1                 |1               |Yes         |Yes               |No                 |Yes                     |NULL                  |NULL               |NULL                         |NULL                         |NULL                           |["liveintent"]             |Affiliate        |
# |Non-Site Activity  |2020-10-11              |2020-10-11 11:12:33+00:00  |35417           |2761209184361  |2020-10-11 11:12:33         |11 - 8d842e74-abfc-4cfd-9bb7-4b5e21344eb0  |8d842e74-abfc-4cfd-9bb7-4b5e21344eb0  |2543402    |3487133892713   |schat.bailey@gmail.com  |recurring_order                                     |api-1ijIphcUTx806K6P5ZF5aq6cdRS            |NULL                  |NULL                 |NULL              |NULL            |NULL                         |NULL                       |NULL                       |NULL                                                |NULL                        |NULL        |NULL                     |NULL                            |NULL                      |NULL                           |NULL               |NULL                      |NULL                                                |NULL            |NULL              |NULL                 |49.0                 |No              |No             |No             |Yes                            |NULL                        |1        |1                      |0                   |0                 |0                     |0                    |1                 |NULL             |NULL          |NULL             |NULL             |NULL                   |NULL                                 |NULL                            |NULL                                 |NULL                                 |NULL                     |NULL                     |NULL                  |NULL                         |NULL                           |NULL                   |1             |2                 |2               |No          |No                |No                 |NULL                    |NULL                  |NULL               |NULL                         |NULL                         |NULL                           |["liveintent"]             |Direct/Other     |
# |Non-Site Activity  |2020-11-10              |2020-11-10 12:14:24+00:00  |39958           |2823550795881  |2020-11-10 12:14:24         |13 - 8d842e74-abfc-4cfd-9bb7-4b5e21344eb0  |8d842e74-abfc-4cfd-9bb7-4b5e21344eb0  |2543402    |3487133892713   |schat.bailey@gmail.com  |recurring_order                                     |api-1k6A4QoSNFAuQ50td6lhT4AUc2N            |NULL                  |NULL                 |NULL              |NULL            |NULL                         |NULL                       |NULL                       |NULL                                                |NULL                        |NULL        |NULL                     |NULL                            |NULL                      |NULL                           |NULL               |NULL                      |NULL                                                |NULL            |NULL              |NULL                 |49.0                 |No              |No             |No             |Yes                            |NULL                        |1        |1                      |0                   |0                 |0                     |0                    |1                 |NULL             |NULL          |NULL             |NULL             |NULL                   |NULL                                 |NULL                            |NULL                                 |NULL                                 |NULL                     |NULL                     |NULL                  |NULL                         |NULL                           |NULL                   |1             |3                 |3               |No          |No                |No                 |NULL                    |NULL                  |NULL               |NULL                         |NULL                         |NULL                           |["liveintent"]             |Direct/Other     |
# |Non-Site Activity  |2020-12-10              |2020-12-10 12:12:35+00:00  |45282           |2908104622185  |2020-12-10 12:12:35         |17 - 8d842e74-abfc-4cfd-9bb7-4b5e21344eb0  |8d842e74-abfc-4cfd-9bb7-4b5e21344eb0  |2543402    |3487133892713   |schat.bailey@gmail.com  |recurring_order                                     |api-1lStYBpkOhMuIeHPekAD4eDqscb            |NULL                  |NULL                 |NULL              |NULL            |NULL                         |NULL                       |NULL                       |NULL                                                |NULL                        |NULL        |NULL                     |NULL                            |NULL                      |NULL                           |NULL               |NULL                      |NULL                                                |NULL            |NULL              |NULL                 |49.0                 |No              |No             |No             |Yes                            |NULL                        |1        |1                      |0                   |0                 |0                     |0                    |1                 |NULL             |NULL          |NULL             |NULL             |NULL                   |NULL                                 |NULL                            |NULL                                 |NULL                                 |NULL                     |NULL                     |NULL                  |NULL                         |NULL                           |NULL                   |1             |4                 |4               |No          |No                |No                 |NULL                    |NULL                  |NULL               |NULL                         |NULL                         |NULL                           |["liveintent"]             |Direct/Other     |
# |Non-Site Activity  |2021-01-09              |2021-01-09 12:08:58+00:00  |51085           |2978796765289  |2021-01-09 12:08:58         |20 - 8d842e74-abfc-4cfd-9bb7-4b5e21344eb0  |8d842e74-abfc-4cfd-9bb7-4b5e21344eb0  |2543402    |3487133892713   |schat.bailey@gmail.com  |recurring_order                                     |api-1mpcog4WvcaO3d46atZ2L5MY7wf            |NULL                  |NULL                 |NULL              |NULL            |NULL                         |NULL                       |NULL                       |NULL                                                |NULL                        |NULL        |NULL                     |NULL                            |NULL                      |NULL                           |NULL               |NULL                      |NULL                                                |NULL            |NULL              |NULL                 |49.0                 |No              |No             |No             |Yes                            |NULL                        |1        |1                      |0                   |0                 |0                     |0                    |1                 |NULL             |NULL          |NULL             |NULL             |NULL                   |NULL                                 |NULL                            |NULL                                 |NULL                                 |NULL                     |NULL                     |NULL                  |NULL                         |NULL                           |NULL                   |1             |5                 |5               |No          |No                |No                 |NULL                    |NULL                  |NULL               |NULL                         |NULL                         |NULL                           |["liveintent"]             |Direct/Other     |
# |Non-Site Activity  |2021-02-08              |2021-02-08 12:10:31+00:00  |56535           |3036130934889  |2021-02-08 12:10:31         |22 - 8d842e74-abfc-4cfd-9bb7-4b5e21344eb0  |8d842e74-abfc-4cfd-9bb7-4b5e21344eb0  |2543402    |3487133892713   |schat.bailey@gmail.com  |recurring_order                                     |api-1oCMjYDohLoHur69uuOs5GDXiar            |NULL                  |NULL                 |NULL              |NULL            |NULL                         |NULL                       |NULL                       |NULL                                                |NULL                        |NULL        |NULL                     |NULL                            |NULL                      |NULL                           |NULL               |NULL                      |NULL                                                |NULL            |NULL              |NULL                 |49.0                 |No              |No             |No             |Yes                            |NULL                        |1        |1                      |0                   |0                 |0                     |0                    |1                 |NULL             |NULL          |NULL             |NULL             |NULL                   |NULL                                 |NULL                            |NULL                                 |NULL                                 |NULL                     |NULL                     |NULL                  |NULL                         |NULL                           |NULL                   |1             |6                 |6               |No          |No                |No                 |NULL                    |NULL                  |NULL               |NULL                         |NULL                         |NULL                           |["liveintent"]             |Direct/Other     |
# |Non-Site Activity  |2021-03-10              |2021-03-10 12:07:41+00:00  |61081           |3665709269097  |2021-03-10 12:07:41         |25 - 8d842e74-abfc-4cfd-9bb7-4b5e21344eb0  |8d842e74-abfc-4cfd-9bb7-4b5e21344eb0  |2543402    |3487133892713   |schat.bailey@gmail.com  |recurring_order                                     |api-1pZ644fT6UEqZ76zk2kxVyx7OPD            |NULL                  |NULL                 |NULL              |NULL            |NULL                         |NULL                       |NULL                       |NULL                                                |NULL                        |NULL        |NULL                     |NULL                            |NULL                      |NULL                           |NULL               |NULL                      |NULL                                                |NULL            |NULL              |NULL                 |49.0                 |No              |No             |No             |Yes                            |NULL                        |1        |1                      |0                   |0                 |0                     |0                    |1                 |NULL             |NULL          |NULL             |NULL             |NULL                   |NULL                                 |NULL                            |NULL                                 |NULL                                 |NULL                     |NULL                     |NULL                  |NULL                         |NULL                           |NULL                   |1             |7                 |7               |No          |No                |No                 |NULL                    |NULL                  |NULL               |NULL                         |NULL                         |NULL                           |["liveintent"]             |Direct/Other     |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
